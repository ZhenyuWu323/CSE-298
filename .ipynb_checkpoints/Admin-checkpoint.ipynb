# %%
import psycopg2
import requests
import json
import pymysql

# %%
host = "gameexplorer.cal8aajyevac.ap-southeast-2.rds.amazonaws.com"
user = 'admin'
password = "wuzhenyu"
database = 'GameExplorer'
connection = pymysql.connect(host=host, user=user, password=password, database=database)
cursor = connection.cursor()
sql = "drop table GameList"
#cursor.execute(sql)
#connection.commit()
sql = '''
        create table GameList(
        id varchar(255),
        name varchar(255),
        background varchar(255),
        genre varchar(255),
        platform varchar(255),
        rating varchar(255),
        metacritic varchar(255),
        stores varchar(255),
        released varchar(255),
        page varchar(255)
        )'''
#cursor.execute(sql)
#connection.commit()

# %%
#1-30
#30-100

# %%
def fetch_game():
    values = []
    #Page number
    for k in range(100,200):
        print(k)
        url = 'https://api.rawg.io/api/games?key=c5cbbf661c79425e9064cd8c3976db42&page='+str(k)
        response = requests.get(url)
        json_data = response.json()
        game_list = json_data['results']
        for i in game_list:
            game_id= i['id']
            # Check if the game with the given ID already exists in the table
            #check_sql = "SELECT COUNT(*) FROM GameList WHERE id = %s" % game_id
            #cursor.execute(check_sql)
            #result = cursor.fetchone()
            #if result[0] > 0:
                #continue
            game_name = i['name'].replace("'", " ")

            image = i['background_image']
            if image != None:
                index = image.index('media/') + len('media/')
                game_image = image[:index] + 'crop/600/400/' + image[index:]

            genres_list = i['genres']
            game_genre = ""
            if genres_list != None:
                for x in genres_list:
                    if x != None:
                        game_genre+= x['name'] + ','
                game_genre = game_genre[:-1]

            platform_list = i['platforms']
            game_platform = ""
            if platform_list != None:
                for j in platform_list:
                    if j != None:
                        j = dict(j)
                        temp = dict(j['platform'])
                        game_platform+= temp['name'] + ','
                game_platform = game_platform[:-1]
            
            game_rating = i['rating']
            game_metacritic = i['metacritic']
            
            stores = i['stores']
            game_stores = ""
            if stores != None:
                for y in range(0, len(stores)):
                    if stores[y] != None:
                        store = stores[y]['store']
                        store_name = store['name']
                        store_domain = store['domain']
                        game_stores += store_name +":" + store_domain + ','
                game_stores = game_stores[:-1]
            
            game_release = i['released']
            values.append((game_id, game_name, game_image, game_genre, game_platform, game_rating, game_metacritic, game_stores,game_release, k))
            #sql = '''insert into GameList (id, name, background, genre, platform, rating, metacritic, stores, page) values ('%s', '%s', '%s', '%s',"%s",'%s','%s','%s', '%d')''' % (game_id,game_name,game_image,game_genre, game_platform, game_rating,game_metacritic, game_stores,k)
            #cursor.execute(sql)
            #connection.commit()
    return values
res = fetch_game()
# Out:
# 100
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File D:\Anaconda\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 63
#      59             #sql = '''insert into GameList (id, name, background, genre, platform, rating, metacritic, stores, page) values ('%s', '%s', '%s', '%s',"%s",'%s','%s','%s', '%d')''' % (game_id,game_name,game_image,game_genre, game_platform, game_rating,game_metacritic, game_stores,k)
#      60             #cursor.execute(sql)
# ...

# %%
print(res[34])
# Out:
# (19103, 'Half-Life 2: Lost Coast', 'https://media.rawg.io/media/crop/600/400/games/b7b/b7b8381707152afc7d91f5d95de70e39.jpg', 'Action', 'macOS,Linux,PC', 3.44, None, 'Steam:store.steampowered.com', '2005-10-27', 2)

# %%
host = "gameexplorer.cal8aajyevac.ap-southeast-2.rds.amazonaws.com"
user = 'admin'
password = "wuzhenyu"
database = 'GameExplorer'
connection = pymysql.connect(host=host, user=user, password=password, database=database)
cursor = connection.cursor()
sql = '''insert into GameList (id, name, background, genre, platform, rating, metacritic, stores,released, page) values (%s, %s, %s, %s, %s, %s, %s, %s,%s, %s)'''
cursor.executemany(sql, res)
connection.commit()

# %%
response = requests.get('https://api.rawg.io/api/games?key=c5cbbf661c79425e9064cd8c3976db42')
json_data = response.json()
game_num = int(json_data['count'])
game_list = json_data['results']
temp = game_list[0]

# %%
print(temp.keys())
print(temp['genres'])
# Out:
# dict_keys(['id', 'slug', 'name', 'released', 'tba', 'background_image', 'rating', 'rating_top', 'ratings', 'ratings_count', 'reviews_text_count', 'added', 'added_by_status', 'metacritic', 'playtime', 'suggestions_count', 'updated', 'user_game', 'reviews_count', 'saturated_color', 'dominant_color', 'platforms', 'parent_platforms', 'genres', 'stores', 'clip', 'tags', 'esrb_rating', 'short_screenshots'])
# [{'id': 4, 'name': 'Action', 'slug': 'action', 'games_count': 172946, 'image_background': 'https://media.rawg.io/media/games/b7b/b7b8381707152afc7d91f5d95de70e39.jpg'}, {'id': 3, 'name': 'Adventure', 'slug': 'adventure', 'games_count': 132715, 'image_background': 'https://media.rawg.io/media/games/951/951572a3dd1e42544bd39a5d5b42d234.jpg'}]

# %%
print(temp['background_image'])
from io import BytesIO
import base64
url = "https://media.rawg.io/media/crop/600/400/games/456/456dea5e1c7e3cd07060c14e96612001.jpg"
response = requests.get(url)
response.raise_for_status()  # Check for any errors during the request

image_data = response.content

# Convert image data to base64
base64_image = base64.b64encode(image_data)
# Out:
# https://media.rawg.io/media/games/456/456dea5e1c7e3cd07060c14e96612001.jpg

# %%
print(base64_image)
# Out:
# b'...'

# %%
url = "https://api.rawg.io/api/games/3498/movies?key=c5cbbf661c79425e9064cd8c3976db42"
